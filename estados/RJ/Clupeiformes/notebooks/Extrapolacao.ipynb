# %%
import pandas as pd
import os

# %%
os.chdir(r'C:\Users\PC\Documents\Proj_MPA\Recontrucao\Alagoas\1-Crustaceos')

# %%
input_path = 'R.xlsx'

# %%
df = pd.read_excel(input_path)

# %%
df = df[['Ano', 'TOTAL_CRUSTACEOS_F&M', 'TOTAL_GROUPS_F&M']].dropna()
df = df[df['TOTAL_GROUPS_F&M'] != 0]
df['Razao_TOTAL_CRUSTACEOS_F&M'] = df['TOTAL_CRUSTACEOS_F&M'] / df['TOTAL_GROUPS_F&M']

# Salvar em um novo arquivo Excel
df.to_excel("Extrapolacao_TOTAL_CRUSTACEOS_F&M.xlsx", index=False)

print("Arquivo 'resultado.xlsx' salvo com sucesso!")
# Out:
# Arquivo 'resultado.xlsx' salvo com sucesso!
